# %%
import pandas as pd
import csv

# %% [markdown]
# ## Get all currently used industry labels as list

# %%
# read csv file
df = pd.read_csv("../data/raw/raw_data.csv")
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4204 entries, 0 to 4203
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   startup_ID                   4204 non-null   int64
#  1   description_startupdetector  583 non-null    object
#  2   startup_description          4072 non-null   object
#  3   industry                     4204 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 131.5+ KB
#    startup_ID                        description_startupdetector
# 0        4330  The company develops software for the analysis...  \
# 1        4707  The company is developing an information and p...
# 2        5255  The company develops bicycle accessories that ...
# 3        5256  The company is developing sensor technology th...
# 4        5257  The company is developing an as yet unknown mo...
#
#   startup_description            industry
# 0                 NaN  manufacturing_tech
# 1                 NaN      education_tech
# 2                 NaN               Sport
# 3                 NaN            Industry
# 4                 NaN             tourism

# %%
# get all unique industry labels
# Split the values in the column
df['split_column'] = df['industry'].str.split(',')

# Explode the lists into separate rows
df_exploded = df.explode('split_column')

# Extract the unique values
unique_values = df_exploded['split_column'].unique()

print(len(unique_values))
# Out:
# 192

# %%
unique_values = sorted(unique_values, key=str.lower)
unique_values
# Out:
# ['additive_manufacturing',
#  'Advertising',
#  'agrar_tech',
#  'AgrarTech',
#  'anti_counterfeit',
#  'Architectural technology',
#  'architectural_technology',
#  'Artificial intelligence',
#  'artificial_intelligence',
#  'Augmented Reality',
#  'augmented_reality',
#  'automotive',
#  'autonomous_driving',
#  'aviation',
#  'battery',
#  'Battery',
#  'bio_informatics',
#  'bio_tech',
#  'BioTech',
#  'blockchain',
#  'Blockchain',
#  'Blockchain / Crypto',
#  'Building automation',
#  'building_automation',
#  'carbon_capture',
#  'charging_station',
#  'chem_tech',
#  'ChemTech',
#  'clean_tech',
#  'Cloud computing',
#  'cloud_computing',
#  'Collaborative Tech',
#  'collaborative_tech',
#  'communication_technology',
#  'computer_vision',
#  'condition_monitoring',
#  'construction',
#  'Construction Tech',
#  'construction_tech',
#  'consultancy',
#  'Consultancy',
#  'consumer_goods',
#  'cosmetics_luxury',
#  'Crafts / DIY',
#  'crafts_diy',
#  'Creative / Design',
#  'creative_design',
#  'Cyber Security',
#  'cyber_security',
#  'Data analytics',
#  'Data management',
#  'data_analytics',
#  'data_management',
#  'devops',
#  'DevOps',
#  'digital_twin',
#  'disability_tech',
#  'E-commerce',
#  'e_commerce',
#  'eCommerce',
#  'EdTech',
#  'Education',
#  'education_tech',
#  'Energy',
#  'Energy & Climate',
#  'energy_tech',
#  'Entertainment',
#  'entertainment_technology',
#  'environmental technology',
#  'erp',
#  'ERP',
#  'exploration_survey',
#  'fin_tech',
#  'financial area',
#  'FinTech',
#  'food_tech',
#  'FoodTech',
#  'forest_economy',
#  'future_work',
#  'Gaming',
#  'gov_tech',
#  'green_building',
#  'Groceries',
#  'Hardware',
#  'health_tech',
#  'HealthTech',
#  'HR Tech',
#  'hr_tech',
#  'hydrogen',
#  'Industry',
#  'Information Technology',
#  'information_privacy',
#  'insurance_tech',
#  'InsurTech',
#  'intra_logistics',
#  'iot',
#  'IoT',
#  'it_tech',
#  'lab_tech',
#  'laser_photonics',
#  'legal advice',
#  'legal_tech',
#  'LegalTech',
#  'Life style',
#  'life_style',
#  'logistics',
#  'Logistics',
#  'Low-carbon economy',
#  'low_carbon',
#  'machine_vision',
#  'maintenance_operation',
#  'Manufacturing',
#  'manufacturing_tech',
#  'mar_tech',
#  'MarTech',
#  'Med & Health',
#  'med_tech',
#  'media',
#  'media_tech',
#  'medicine',
#  'MedTech',
#  'micro_mobility',
#  'microtechnology',
#  'Microtechnology',
#  'mobility',
#  'Mobility & Transportation',
#  'mobility_transport',
#  'neuro_technology',
#  'New material',
#  'new_material',
#  'packaging',
#  'Packaging',
#  'Personal',
#  'pets_animals',
#  'pharma_tech',
#  'PharmaTech',
#  'Production & Supply Chain',
#  'prop_tech',
#  'property',
#  'quantum_computing',
#  'quantum_technology',
#  'rail_transport',
#  'recycling',
#  'Recycling',
#  'retail_tech',
#  'RetailTech',
#  'robot',
#  'Robot',
#  'safety',
#  'Safety',
#  'Search & Rescue',
#  'search_and_rescue',
#  'sensor_actuator',
#  'service',
#  'Sharing economy',
#  'sharing_economy',
#  'simulation_tech',
#  'Smart Mobility',
#  'smart_home',
#  'smart_mobility',
#  'social_tech',
#  'SocialTech',
#  'Software',
#  'Solar power',
#  'solar_power',
#  'space_tech',
#  'SpaceTech',
#  'Sport',
#  'sports_tech',
#  'SportsTech',
#  'Supply chain',
#  'supply_chain',
#  'sustainability',
#  'Sustainability',
#  'Sustainability & GreenTech',
#  'technical_safety',
#  'textile_tech',
#  'TextileTech',
#  'tourism',
#  'track_trace',
#  'travel_tech',
#  'TravelTech',
#  'unknown',
#  'Unknown',
#  'user_interface',
#  'utility_tech',
#  'Virtual Reality',
#  'virtual_reality',
#  'water_management',
#  'wearables',
#  'Web development',
#  'web_development']

# %%
fields = ['INDUSTRY']
rows = []
for item in unique_values:
    rows.append([item])

with open('../data/industry_tags_unique.csv', 'w', newline='') as f:
      
    # using csv.writer method from CSV package
    write = csv.writer(f)
      
    write.writerow(fields)
    write.writerows(rows)

# %%
# create data frame with industry labels
df = pd.DataFrame(unique_values, columns=['unique_values'])

# create industry match by lowercasing and removing special characters
def transform_industry_for_matching(industry):
    industry = industry.strip()
    industry = industry.lower()
    industry = ''.join(e for e in industry if e.isalnum())
    return industry
df['industry_match'] = df['unique_values'].apply(transform_industry_for_matching)

df.head()
# Out:
#             unique_values         industry_match
# 0  additive_manufacturing  additivemanufacturing
# 1             Advertising            advertising
# 2              agrar_tech              agrartech
# 3               AgrarTech              agrartech
# 4        anti_counterfeit        anticounterfeit

# %%
# read in nuntium tech labels
n_df = pd.read_csv('../data/gruendermotor-tech-labels.csv')
n_df['industry_match'] = n_df['Label'].apply(transform_industry_for_matching)
n_df.head()
# Out:
#           Label      Type      molecule industry_match
# 0       Unknown  MOLECULE           NaN        unknown
# 1  Med & Health  MOLECULE           NaN      medhealth
# 2       MedTech      ATOM  Med & Health        medtech
# 3    HealthTech      ATOM  Med & Health     healthtech
# 4    PharmaTech      ATOM  Med & Health     pharmatech

# %%
# add molecule to unique industry label
m_df = df.merge(n_df[['molecule', 'industry_match']], 'left', 'industry_match')
m_df.to_csv('../data/industry_label_merge.csv')
m_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   unique_values   192 non-null    object
#  1   industry_match  192 non-null    object
#  2   molecule        153 non-null    object
# dtypes: object(3)
# memory usage: 4.6+ KB

# %%
# read in filled merge dataframe
industry_match = pd.read_csv('../data/industry_label_merge_filled.csv')
industry_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   unique_values   192 non-null    object
#  1   industry_match  192 non-null    object
#  2   molecule        192 non-null    object
# dtypes: object(3)
# memory usage: 4.6+ KB

# %%
# merge new industry tag to original exploded df
new = df_exploded.merge(industry_match[['unique_values', 'molecule']], 'left', left_on='split_column', right_on='unique_values')
new.tail()
# Out:
#       startup_ID description_startupdetector
# 6898        5486                         NaN  \
# 6899        5486                         NaN
# 6900        5486                         NaN
# 6901        5184                         NaN
# 6902        5184                         NaN
#
#                                     startup_description
# 6898  ZURÜCK gives textiles from the hotel industry ...  \
# 6899  ZURÜCK gives textiles from the hotel industry ...
# 6900  ZURÜCK gives textiles from the hotel industry ...
# 6901  µWind designs, produces and sells small wind t...
# 6902  µWind designs, produces and sells small wind t...
#
#                                     industry     split_column
# 6898  recycling,creative_design,textile_tech        recycling  \
# 6899  recycling,creative_design,textile_tech  creative_design
# 6900  recycling,creative_design,textile_tech     textile_tech
# 6901                  smart_home,energy_tech       smart_home
# 6902                  smart_home,energy_tech      energy_tech
#
#         unique_values                    molecule
# 6898        recycling  Sustainability & GreenTech
# 6899  creative_design             Retail & Living
# 6900     textile_tech        Materials & Deeptech
# 6901       smart_home             Retail & Living
# 6902      energy_tech            Energy & Climate

# %%
print(new.info())
new = new.drop_duplicates(subset=['startup_ID'], keep='first')
print(new.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6903 entries, 0 to 6902
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   startup_ID                   6903 non-null   int64
#  1   description_startupdetector  953 non-null    object
#  2   startup_description          6771 non-null   object
#  3   industry                     6903 non-null   object
#  4   split_column                 6903 non-null   object
#  5   unique_values                6903 non-null   object
#  6   molecule                     6903 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 377.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 4204 entries, 0 to 6901
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   startup_ID                   4204 non-null   int64
#  1   description_startupdetector  583 non-null    object
#  2   startup_description          4072 non-null   object
#  3   industry                     4204 non-null   object
#  4   split_column                 4204 non-null   object
#  5   unique_values                4204 non-null   object
#  6   molecule                     4204 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 262.8+ KB
# None

# %%
new.tail()
# Out:
#       startup_ID description_startupdetector
# 6894        2967                         NaN  \
# 6896        2947                         NaN
# 6897         852                         NaN
# 6898        5486                         NaN
# 6901        5184                         NaN
#
#                                     startup_description
# 6894  ZU master students Jan Schmiedgen and Christia...  \
# 6896  ZU student Jeanette Orminski and ZU alumnus Ti...
# 6897  Zündholz is a brand strategy and design agency...
# 6898  ZURÜCK gives textiles from the hotel industry ...
# 6901  µWind designs, produces and sells small wind t...
#
#                                     industry        split_column
# 6894       collaborative_tech,sustainability  collaborative_tech  \
# 6896                                 hr_tech             hr_tech
# 6897                          user_interface      user_interface
# 6898  recycling,creative_design,textile_tech           recycling
# 6901                  smart_home,energy_tech          smart_home
#
#            unique_values                    molecule
# 6894  collaborative_tech           People & Learning
# 6896             hr_tech           People & Learning
# 6897      user_interface            Data & Computing
# 6898           recycling  Sustainability & GreenTech
# 6901          smart_home             Retail & Living

# %%
# only keep necessary columns and save as raw_data.csv
raw_data = new.drop(columns=['industry', 'split_column', 'unique_values'])
raw_data = raw_data.rename(columns={"molecule": "industry"})
raw_data.to_csv('../data/small_labels/raw_data.csv')
